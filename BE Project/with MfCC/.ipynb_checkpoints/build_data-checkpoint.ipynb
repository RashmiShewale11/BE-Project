# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display

# %matplotlib inline

# %%
df = pd.read_csv('/home/rashmi/Dataset/pre-processed/audio_features.csv')
df = df[df['label'].isin([0, 1, 2, 3, 4, 5, 6, 7])]
print(df.shape)
display(df.head())

# change 7 to 2
df['label'] = df['label'].map({0: 0, 1: 1, 2: 1, 3: 2, 4: 2, 5: 3, 6: 4, 7: 5})
df.head()
# Out:
# (1646, 10)
#               wav_file  label  sig_mean   sig_std  rmse_mean  rmse_std  \
# 1  Ses05F_impro02_F001      3  0.001328  0.001970   0.001643  0.001089
# 2  Ses05F_impro02_F002      3  0.003095  0.005409   0.003954  0.003688
# 4  Ses05F_impro02_F004      3  0.002462  0.004614   0.003229  0.003285
# 5  Ses05F_impro02_F005      3  0.002656  0.004256   0.003388  0.002573
# 6  Ses05F_impro02_F006      5  0.002445  0.004712   0.003048  0.003574
#
#     silence  harmonic  auto_corr_max  auto_corr_std
# 1  0.000000 -0.006624       0.002614       0.008292
# 2  0.266393 -0.008770       0.022267       0.065142
# 4  0.326633 -0.012447       0.016857       0.030454
# 5  0.368771 -0.010221       0.012970       0.041462
# 6  0.210084 -0.008982       0.017823       0.050950
#               wav_file  label  sig_mean   sig_std  rmse_mean  rmse_std  \
# 1  Ses05F_impro02_F001      2  0.001328  0.001970   0.001643  0.001089
# ...

# %%
df.to_csv('/home/madhura/Dataset/pre-processed/no_sample_df.csv')

# oversample fear
fear_df = df[df['label']==3]
for i in range(30):
    df = df.append(fear_df)

sur_df = df[df['label']==4]
for i in range(10):
    df = df.append(sur_df)
    
df.to_csv('/home/madhura/Dataset/pre-processed/modified_df.csv')

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'neu': 3,}

# emotion_dict = {'ang': 0,
#                 'hap': 1,
#                 'exc': 2,
#                 'sad': 3,
#                 'fru': 4,
#                 'fea': 5,
#                 'sur': 6,
#                 'neu': 7,
#                 'xxx': 8,
#                 'oth': 8}

scalar = MinMaxScaler()
df[df.columns[2:]] = scalar.fit_transform(df[df.columns[2:]])
df.head()
# Out:
#               wav_file  label  sig_mean   sig_std  rmse_mean  rmse_std  \
# 1  Ses05F_impro02_F001      2  0.002717  0.003897   0.002635  0.008192
# 2  Ses05F_impro02_F002      2  0.017503  0.024039   0.018318  0.033716
# 4  Ses05F_impro02_F004      2  0.012205  0.019382   0.013401  0.029753
# 5  Ses05F_impro02_F005      2  0.013833  0.017285   0.014475  0.022769
# 6  Ses05F_impro02_F006      3  0.012064  0.019953   0.012170  0.032588
#
#     silence  harmonic  auto_corr_max  auto_corr_std
# 1  0.000000  0.882554       0.000088       0.000135
# 2  0.351878  0.874560       0.001127       0.001481
# 4  0.431448  0.860859       0.000841       0.000660
# 5  0.487108  0.869154       0.000635       0.000921
# 6  0.277499  0.873770       0.000892       0.001145

# %%
x_train, x_test = train_test_split(df, test_size=0.20)

x_train.to_csv('/home/madhura/Dataset/pre-processed/s2e/audio_train.csv', index=False)
x_test.to_csv('/home/madhura/Dataset/pre-processed/s2e/audio_test.csv', index=False)

print(x_train.shape, x_test.shape)
# Out:
# (10724, 10) (2682, 10)
