# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from IPython.display import display

# %matplotlib inline

# %%
df = pd.read_csv('/home/rashmi/Dataset/pre-processed-mfcc/audio_features.csv')
df = df[df['label'].isin([0, 1, 2, 3, 4, 5, 6, 7])]
print(df.shape)
display(df.head())

# change 7 to 2
df['label'] = df['label'].map({0: 0, 1: 1, 2: 1, 3: 2, 4: 2, 5: 3, 6: 4, 7: 5})
df.head()
# Out:
# (1650, 23)
#               wav_file  label  sig_mean   sig_std  rmse_mean  rmse_std  \
# 0  Ses05F_impro04_F000      3  0.001448  0.002092   0.001799  0.001071
# 2  Ses05F_impro04_F002      4  0.005108  0.008415   0.006424  0.005437
# 3  Ses05F_impro04_F003      4  0.005829  0.008689   0.007171  0.004913
# 4  Ses05F_impro04_F004      4  0.006648  0.011370   0.008352  0.007713
# 5  Ses05F_impro04_F005      4  0.008542  0.014262   0.010917  0.009141
#
#     silence  harmonic  auto_corr_max  auto_corr_std  ...      mfcc4  \
# 0  0.000000 -0.009782       0.002868       0.016217  ...  27.407269
# 2  0.338358 -0.007737       0.051528       0.231741  ...   8.698827
# 3  0.212885 -0.008300       0.050660       0.347343  ...  16.617832
# 4  0.279835 -0.008103       0.096715       0.522334  ...  14.567813
# 5  0.271429 -0.011282       0.149683       0.200129  ...   5.249462
#
#        mfcc5      mfcc6      mfcc7     mfcc8      mfcc9     mfcc10    mfcc11  \
# ...

# %%
df.to_csv('/home/rashmi/Dataset/pre-processed-mfcc/no_sample_df.csv')

# oversample fear
fear_df = df[df['label']==3]
for i in range(30):
    df = df.append(fear_df)

sur_df = df[df['label']==4]
for i in range(10):
    df = df.append(sur_df)
    
df.to_csv('/home/rashmi/Dataset/pre-processed-mfcc/modified_df.csv')

# %%
emotion_dict = {'ang': 0,
                'hap': 1,
                'sad': 2,
                'neu': 3,}

# emotion_dict = {'ang': 0,
#                 'hap': 1,
#                 'exc': 2,
#                 'sad': 3,
#                 'fru': 4,
#                 'fea': 5,
#                 'sur': 6,
#                 'neu': 7,
#                 'xxx': 8,
#                 'oth': 8}

scalar = MinMaxScaler()
df[df.columns[2:]] = scalar.fit_transform(df[df.columns[2:]])
df.head()
# Out:
#               wav_file  label  sig_mean   sig_std  rmse_mean  rmse_std  \
# 0  Ses05F_impro04_F000      2  0.003722  0.004612   0.003693  0.008015
# 2  Ses05F_impro04_F002      2  0.034343  0.041643   0.035080  0.050880
# 3  Ses05F_impro04_F003      2  0.040376  0.043248   0.040151  0.045740
# 4  Ses05F_impro04_F004      2  0.047231  0.058952   0.048162  0.073235
# 5  Ses05F_impro04_F005      2  0.063072  0.075886   0.065572  0.087251
#
#     silence  harmonic  auto_corr_max  auto_corr_std  ...     mfcc4     mfcc5  \
# 0  0.000000  0.870790       0.000101       0.000323  ...  0.720364  0.515120
# 2  0.446936  0.878408       0.002673       0.005426  ...  0.389270  0.397513
# 3  0.281199  0.876311       0.002627       0.008163  ...  0.529417  0.475701
# 4  0.369633  0.877046       0.005061       0.012307  ...  0.493137  0.385281
# 5  0.358529  0.865200       0.007861       0.004677  ...  0.328225  0.409503
#
#       mfcc6     mfcc7     mfcc8     mfcc9    mfcc10    mfcc11    mfcc12  \
# ...

# %%
x_train, x_test = train_test_split(df, test_size=0.20)

x_train.to_csv('/home/rashmi/Dataset/pre-processed-mfcc/s2e/audio_train.csv', index=False)
x_test.to_csv('/home/rashmi/Dataset/pre-processed-mfcc/s2e/audio_test.csv', index=False)

print(x_train.shape, x_test.shape)
# Out:
# (1704, 23) (426, 23)
